# %%
from selenium import webdriver

# %%
browser = webdriver.Chrome('C:\projects\drivers\chromedriver.exe')

# %%
browser.get('https://techstepacademy.com/training-ground')

# %%
input_field = browser.find_element_by_css_selector('input[id="ipt1"]')

# %%
input_field
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="19d9d45bdb41cc136e2d5fc91cbcb198", element="ade4ee43-9060-4230-aa11-75eee0829051")>

# %%
input_field.send_keys('Field input')

# %%
button2 = browser.find_element_by_css_selector('button[id="b2"]')

# %%
button2.click()

# %%
import sys

# %%
sys.version
# Out:
# '3.9.2 (tags/v3.9.2:1a79785, Feb 19 2021, 13:44:55) [MSC v.1928 64 bit (AMD64)]'

# %%
input2_css_locator = 'input[id="ipt2"]'

# %%
button4_xpath_locator = '//button[@id="b4"]'

# %%
product1_xpath_locator = "$x('//b[text()="Product 1"]/../../p')"

# %%
input2_elem = browser.find_element_by_css_selector(input2_css_locator)

# %%
butn4_elem = browser.find_element_by_xpath(button4_xpath_locator)

# %%
input2_elem.send_keys("Test")

# %%
butn4_elem.click()

# %%
browser.quit()
